# %%
import pandas as pd
import numpy as np

# %%
final_preds = pd.read_csv('final_validation.csv')
final_preds_title = final_preds[['File', 'prediction_by_title']]
final_preds_abstract = final_preds[['File', 'prediction_by_abstract']]
final_preds_text = final_preds[['File', 'prediction_by_text']]

# %%
final_preds_title
# Out:
#                                            File prediction_by_title
# 0     ABC_G1B1_10.1016_j.energy.2018.11.091.txt                SDG7
# 1   ABC_G1B2_10.1016_j.apenergy.2018.01.084.txt                SDG3
# 2      ABC_G1B2_10.1016_j.enpol.2020.111284.txt               SDG10
# 3    ABC_G1B2_10.1016_j.jclepro.2020.121262.txt               SDG13
# 4     ABC_G1B2_10.1016_j.renene.2020.05.131.txt               SDG10
# ..                                          ...                 ...
# 94        RST_G7B4_10.1016_j.scitotenv.2020.txt               SDG13
# 95     RST_G7B4_10.1016_j.uclim.2020.100599.txt               SDG13
# 96                  RST_G7B4_PANGAEA.884782.txt               SDG13
# 97               RST_G7B4_S0959378012001288.txt               SDG13
# 98               RST_G7B4_S1574954113000241.txt               SDG13
#
# [99 rows x 2 columns]

# %%
final_preds_abstract
# Out:
#                                            File prediction_by_abstract
# 0     ABC_G1B1_10.1016_j.energy.2018.11.091.txt                  SDG13
# 1   ABC_G1B2_10.1016_j.apenergy.2018.01.084.txt                  SDG10
# 2      ABC_G1B2_10.1016_j.enpol.2020.111284.txt                   SDG3
# 3    ABC_G1B2_10.1016_j.jclepro.2020.121262.txt                  SDG10
# 4     ABC_G1B2_10.1016_j.renene.2020.05.131.txt                  SDG10
# ..                                          ...                    ...
# 94        RST_G7B4_10.1016_j.scitotenv.2020.txt                  SDG13
# 95     RST_G7B4_10.1016_j.uclim.2020.100599.txt                  SDG13
# 96                  RST_G7B4_PANGAEA.884782.txt                  SDG13
# 97               RST_G7B4_S0959378012001288.txt                  SDG13
# 98               RST_G7B4_S1574954113000241.txt                  SDG13
#
# [99 rows x 2 columns]

# %%
final_preds_title = final_preds_title.rename({"File": "Filename", "prediction_by_title": "Prediction"}, axis='columns')
final_preds_abstract = final_preds_abstract.rename({"File": "Filename", "prediction_by_abstract": "Prediction"}, axis='columns')
final_preds_text = final_preds_text.rename({"File": "Filename", "prediction_by_text": "Prediction"}, axis='columns')

final_preds_title
# Out:
#                                        Filename Prediction
# 0     ABC_G1B1_10.1016_j.energy.2018.11.091.txt       SDG7
# 1   ABC_G1B2_10.1016_j.apenergy.2018.01.084.txt       SDG3
# 2      ABC_G1B2_10.1016_j.enpol.2020.111284.txt      SDG10
# 3    ABC_G1B2_10.1016_j.jclepro.2020.121262.txt      SDG13
# 4     ABC_G1B2_10.1016_j.renene.2020.05.131.txt      SDG10
# ..                                          ...        ...
# 94        RST_G7B4_10.1016_j.scitotenv.2020.txt      SDG13
# 95     RST_G7B4_10.1016_j.uclim.2020.100599.txt      SDG13
# 96                  RST_G7B4_PANGAEA.884782.txt      SDG13
# 97               RST_G7B4_S0959378012001288.txt      SDG13
# 98               RST_G7B4_S1574954113000241.txt      SDG13
#
# [99 rows x 2 columns]

# %%
final_preds_abstract
# Out:
#                                        Filename Prediction
# 0     ABC_G1B1_10.1016_j.energy.2018.11.091.txt      SDG13
# 1   ABC_G1B2_10.1016_j.apenergy.2018.01.084.txt      SDG10
# 2      ABC_G1B2_10.1016_j.enpol.2020.111284.txt       SDG3
# 3    ABC_G1B2_10.1016_j.jclepro.2020.121262.txt      SDG10
# 4     ABC_G1B2_10.1016_j.renene.2020.05.131.txt      SDG10
# ..                                          ...        ...
# 94        RST_G7B4_10.1016_j.scitotenv.2020.txt      SDG13
# 95     RST_G7B4_10.1016_j.uclim.2020.100599.txt      SDG13
# 96                  RST_G7B4_PANGAEA.884782.txt      SDG13
# 97               RST_G7B4_S0959378012001288.txt      SDG13
# 98               RST_G7B4_S1574954113000241.txt      SDG13
#
# [99 rows x 2 columns]

# %%
final_preds_text
# Out:
#                                        Filename Prediction
# 0     ABC_G1B1_10.1016_j.energy.2018.11.091.txt       SDG7
# 1   ABC_G1B2_10.1016_j.apenergy.2018.01.084.txt      SDG10
# 2      ABC_G1B2_10.1016_j.enpol.2020.111284.txt       SDG3
# 3    ABC_G1B2_10.1016_j.jclepro.2020.121262.txt      SDG13
# 4     ABC_G1B2_10.1016_j.renene.2020.05.131.txt      SDG10
# ..                                          ...        ...
# 94        RST_G7B4_10.1016_j.scitotenv.2020.txt      SDG13
# 95     RST_G7B4_10.1016_j.uclim.2020.100599.txt      SDG13
# 96                  RST_G7B4_PANGAEA.884782.txt      SDG13
# 97               RST_G7B4_S0959378012001288.txt      SDG13
# 98               RST_G7B4_S1574954113000241.txt      SDG13
#
# [99 rows x 2 columns]

# %%
final_preds_title.to_csv('group7_sdg_predictions_by_title.csv')
final_preds_abstract.to_csv('group7_sdg_predictions_by_abstract.csv')
final_preds_text.to_csv('group7_sdg_predictions_by_text.csv')

# %% [markdown]
# ------------------------------------------------
