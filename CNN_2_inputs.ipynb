# %%
import re
import tarfile
from pathlib import Path
from time import time
from functools import reduce
from pprint import pprint
from typing import List, Tuple

import numpy as np
import pandas as pd
from tensorflow.python.keras import layers
from tensorflow.python.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, concatenate, Input,Convolution2D, MaxPooling1D, Dense, Dropout, Flatten,LSTM
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.layers import Dense, Dropout, Activation
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.utils.data_utils import get_file
from tensorflow.python.keras.models import Sequential
from tqdm import tqdm

# %%
#import the already preprocessed dataset 
sdg_df  = pd.read_csv('sdg_classification_data.csv')
sdg_df
# Out:
#      Unnamed: 0  extracted                                 extracted_abstract  \
# 0             0       True  paper attempts empirically analyze compatibili...
# 1             1       True  aim study determine nature relationship renewa...
# 2             2       True  study combines panel data techniques wavelet s...
# 3             3       True  environmental issues dependence fossil fuel so...
# 4             4       True  environmental issues dependence fossil fuel so...
# 5             5       True  blockchain technology ushering nothing short d...
# 6             6       True  blockchain technology ushering nothing short d...
# 7             7       True  paper estimates impact renewable energy econom...
# 8             8       True  paper estimates impact renewable energy econom...
# 9             9       True  increasing concerns environmental economic imp...
# 10           10       True  increasing concerns environmental economic imp...
# 11           11       True  account continuously increasing electricity co...
# 12           12       True  account continuously increasing electricity co...
# 13           13       True  paper aims analyze interaction renewable energ...
# 14           14       True  paper aims analyze interaction renewable energ...
# 15           15       True  middle east north africa mena countries recent...
# 16           16       True  middle east north africa mena countries recent...
# 17           17       True  study investigates dynamic directional informa...
# 18           18       True  study investigates dynamic directional informa...
# 19           19       True  united nations announced new sustainable devel...
# 20           20       True  united nations announced new sustainable devel...
# 21           21      False  current study discusses linear nonlinear relat...
# 22           22      False  current study discusses linear nonlinear relat...
# 23           23       True  renewable energy sources solar panels energy s...
# 24           24      False  currently european union eu population live ho...
# 25           25       True  republic ghana aims develop utilise renewable ...
# 26           26      False  major challenge facing humans st century strik...
# 27           27       True  despite increasing cost competitiveness contin...
# 28           28       True  paper explains adverse effects due massive inj...
# 29           29       True  paper develop quantitative indicator approach ...
# ..          ...        ...                                                ...
# 869         869       True  study analyzes effects impacts policies could ...
# 870         870      False  easy energy access trigger human social econom...
# 871         871      False  china proposed clean energy target together cl...
# 872         872       True  background billion people cook solid fuels res...
# 873         873       True  background access sustained adoption clean hou...
# 874         874       True  background kerosene recently considered relati...
# 875         875      False  india recently launched national biomass cooks...
# 876         876      False  rural household access clean affordable modern...
# 877         877      False  air pollution linked many united nations susta...
# 878         878      False  understanding scale nature hydrogens potential...
# 879         879      False  evidence north india despite widespread global...
# 880         880      False  environmental risk factors especially air wate...
# 881         881       True  background acute lower respiratory infections ...
# 882         882       True  abstractabstract vehicular pollution environme...
# 883         883       True  abstract worlds climate gradually altered burn...
# 884         884      False  two primary objectives recent energy initiativ...
# 885         885       True  abstractthe increasing price fossil fuels coup...
# 886         886      False  associated harmful environmental health social...
# 887         887       True  abstract abstract chinese energy system major ...
# 2    ['energy', 'consumption', 'gdp', 'revisited', ...
# 3    ['multiple', 'perspective', 'modeling', 'simul...
# 4    ['multiple', 'perspective', 'modeling', 'simul...
# 5    ['integrating', 'blockchain', 'technology', 'e...
# 6    ['integrating', 'blockchain', 'technology', 'e...
# 7    ['renewable', 'energy', 'consumption', 'econom...
# 8    ['renewable', 'energy', 'consumption', 'econom...
# 9    ['optimal', 'renewable', 'energy', 'supply', '...
# 10   ['optimal', 'renewable', 'energy', 'supply', '...
# 11   ['review', 'recent', 'sizing', 'methodologies'...
# 12   ['review', 'recent', 'sizing', 'methodologies'...
# 13   ['renewable', 'energy', 'consumption', 'indust...
# 14   ['renewable', 'energy', 'consumption', 'indust...
# 15   ['governance', 'renewable', 'energy', 'investm...
# 16   ['governance', 'renewable', 'energy', 'investm...
# 17   ['dynamic', 'dependence', 'fossil', 'energy', ...
# 18   ['dynamic', 'dependence', 'fossil', 'energy', ...
# 19   ['novel', 'renewable', 'energy', 'selection', ...
# 20   ['novel', 'renewable', 'energy', 'selection', ...
# 21   ['renewable', 'nonrenewable', 'categories', 'e...
# 22   ['renewable', 'nonrenewable', 'categories', 'e...
# 23   ['effect', 'increased', 'buildingintegrated', ...
# 24   ['energy', 'consumption', 'heating', 'costs', ...
# 25   ['ghana', 'achieve', 'renewable', 'energy', 't...
# 26   ['renewable', 'energy', 'consumption', 'eu', '...
# 27   ['dismantling', 'renewable', 'energy', 'polici...
# 28   ['storage', 'cost', 'induced', 'large', 'subst...
# 29   ['comprehensive', 'indicator', 'set', 'measuri...
# ..                                                 ...
# 869  ['assessment', 'chinas', 'climate', 'commitmen...
# 870  ['energy', 'access', 'transition', 'cleaner', ...
# 871  ['chinas', 'clean', 'energy', 'target', 'consi...
# 872  ['reallife', 'effectiveness', 'improved', 'sto...
# 873  ['clean', 'fuels', 'resourcepoor', 'settings',...
# 874  ['adverse', 'health', 'impacts', 'cooking', 'k...
# 875  ['indian', 'national', 'initiative', 'advanced...
# 876  ['rural', 'household', 'fuel', 'energy', 'tran...
# 877  ['outlook', 'clean', 'air', 'context', 'sustai...
# 878  ['production', 'hydrogen', 'fuel', 'renewable'...
# 879  ['much', 'alternative', 'cookstoves', 'reduce'...
# 880  ['environmental', 'health', 'china', 'progress...
# 881  ['cooking', 'season', 'risk', 'factors', 'acut...
# 882  ['effect', 'hydrogen', 'supplementation', 'eng...
# 883  ['bio', 'energy', 'production', 'using', 'carb...
# 884  ['us', 'energy', 'independence', 'assessment',...
# 885  ['modelling', 'smart', 'domestic', 'energy', '...
# 886  ['biogas', 'potential', 'renewable', 'energy',...
# 887  ['greenhouse', 'gas', 'emissions', 'reduction'...
# 888  ['green', 'renewable', 'biodiesel', 'produce',...
# 889  ['lca', 'solar', 'heating', 'cooling', 'system...
# 890    ['exergy', 'analysis', 'chemical', 'processes']
# 891  ['green', 'revolution', 'human', 'resource', '...
# 892  ['upcoming', 'power', 'crisis', 'india', 'incr...
# 893  ['emissions', 'mitigation', 'infrastructure', ...
# 894  ['africa', 'sustainable', 'energy', 'goal', 'f...
# 895  ['scalingup', 'sustainable', 'renewable', 'ene...
# 896  ['brief', 'review', 'application', 'laser', 'b...
# 897  ['electric', 'vehicles', 'impacts', 'integrati...
# 898  ['leading', 'global', 'energy', 'environmental...
#
#                           extracted_abstract_tokenized  \
# 0    ['paper', 'attempts', 'empirically', 'analyze'...
# 1    ['aim', 'study', 'determine', 'nature', 'relat...
# 2    ['study', 'combines', 'panel', 'data', 'techni...
# 3    ['environmental', 'issues', 'dependence', 'fos...
# 4    ['environmental', 'issues', 'dependence', 'fos...
# 5    ['blockchain', 'technology', 'ushering', 'noth...
# 6    ['blockchain', 'technology', 'ushering', 'noth...
# 7    ['paper', 'estimates', 'impact', 'renewable', ...
# 8    ['paper', 'estimates', 'impact', 'renewable', ...
# 9    ['increasing', 'concerns', 'environmental', 'e...
# 10   ['increasing', 'concerns', 'environmental', 'e...
# 11   ['account', 'continuously', 'increasing', 'ele...
# 12   ['account', 'continuously', 'increasing', 'ele...
# 13   ['paper', 'aims', 'analyze', 'interaction', 'r...
# 14   ['paper', 'aims', 'analyze', 'interaction', 'r...
# 15   ['middle', 'east', 'north', 'africa', 'mena', ...
# 16   ['middle', 'east', 'north', 'africa', 'mena', ...
# 17   ['study', 'investigates', 'dynamic', 'directio...
# 18   ['study', 'investigates', 'dynamic', 'directio...
# 19   ['united', 'nations', 'announced', 'new', 'sus...
# 20   ['united', 'nations', 'announced', 'new', 'sus...
# 21   ['current', 'study', 'discusses', 'linear', 'n...
# 22   ['current', 'study', 'discusses', 'linear', 'n...
# 23   ['renewable', 'energy', 'sources', 'solar', 'p...
# 24   ['currently', 'european', 'union', 'eu', 'popu...
# 25   ['republic', 'ghana', 'aims', 'develop', 'util...
# 26   ['major', 'challenge', 'facing', 'humans', 'st...
# 27   ['despite', 'increasing', 'cost', 'competitive...
# 28   ['paper', 'explains', 'adverse', 'effects', 'd...
# 29   ['paper', 'develop', 'quantitative', 'indicato...
# ..                                                 ...
# 869  ['study', 'analyzes', 'effects', 'impacts', 'p...
# 870  ['easy', 'energy', 'access', 'trigger', 'human...
# 871  ['china', 'proposed', 'clean', 'energy', 'targ...
# 872  ['background', 'billion', 'people', 'cook', 's...
# 873  ['background', 'access', 'sustained', 'adoptio...
# 874  ['background', 'kerosene', 'recently', 'consid...
# 875  ['india', 'recently', 'launched', 'national', ...
# 876  ['rural', 'household', 'access', 'clean', 'aff...
# 877  ['air', 'pollution', 'linked', 'many', 'united...
# 878  ['understanding', 'scale', 'nature', 'hydrogen...
# 879  ['evidence', 'north', 'india', 'despite', 'wid...
# 880  ['environmental', 'risk', 'factors', 'especial...
# 881  ['background', 'acute', 'lower', 'respiratory'...
# 882  ['abstractabstract', 'vehicular', 'pollution',...
# 883  ['abstract', 'worlds', 'climate', 'gradually',...
# 884  ['two', 'primary', 'objectives', 'recent', 'en...
# 885  ['abstractthe', 'increasing', 'price', 'fossil...
# 886  ['associated', 'harmful', 'environmental', 'he...
# 887  ['abstract', 'abstract', 'chinese', 'energy', ...
# 888  ['abstract', 'abstract', 'green', 'renewable',...
# 889  ['development', 'renewable', 'energy', 'techno...
# 890  ['abstract', 'exergy', 'analysis', 'exa', 'gai...
# 891  ['introductionmahatma', 'gandhi', 'said', 'nat...
# 892  ['abstract', 'world', 'modernization', 'every'...
# 893  ['abstract', 'order', 'foster', 'development',...
# 894  ['sustainable', 'development', 'goal', 'sdg', ...
# 895  ['three', 'processes', 'urbanization', 'indust...
# 896  ['abstract', 'bioenergy', 'production', 'bioma...
# 897  ['exponential', 'rise', 'electricity', 'demand...
# 898  ['recent', 'years', 'ten', 'member', 'countrie...
#
#                                 initial_text_tokenized
# 0    ['trade', 'liberalization', 'policies', 'align...
# 1    ['oil', 'prices', 'macroeconomic', 'factors', ...
# 2    ['energy', 'consumption', 'gdp', 'revisited', ...
# 3    ['multiple', 'perspective', 'modeling', 'simul...
# 4    ['multiple', 'perspective', 'modeling', 'simul...
# 5    ['integrating', 'blockchain', 'technology', 'e...
# 6    ['integrating', 'blockchain', 'technology', 'e...
# 7    ['renewable', 'energy', 'consumption', 'econom...
# 8    ['renewable', 'energy', 'consumption', 'econom...
# 9    ['optimal', 'renewable', 'energy', 'supply', '...
# 10   ['optimal', 'renewable', 'energy', 'supply', '...
# 11   ['review', 'recent', 'sizing', 'methodologies'...
# 12   ['review', 'recent', 'sizing', 'methodologies'...
# 13   ['renewable', 'energy', 'consumption', 'indust...
# 14   ['renewable', 'energy', 'consumption', 'indust...
# 15   ['governance', 'renewable', 'energy', 'investm...
# 16   ['governance', 'renewable', 'energy', 'investm...
# 17   ['dynamic', 'dependence', 'fossil', 'energy', ...
# 18   ['dynamic', 'dependence', 'fossil', 'energy', ...
# 19   ['novel', 'renewable', 'energy', 'selection', ...
# 20   ['novel', 'renewable', 'energy', 'selection', ...
# 21   ['renewable', 'nonrenewable', 'categories', 'e...
# 22   ['renewable', 'nonrenewable', 'categories', 'e...
# 23   ['effect', 'increased', 'buildingintegrated', ...
# 24   ['energy', 'consumption', 'heating', 'costs', ...
# 25   ['ghana', 'achieve', 'renewable', 'energy', 't...
# 26   ['renewable', 'energy', 'consumption', 'eu', '...
# 27   ['dismantling', 'renewable', 'energy', 'polici...
# 28   ['storage', 'cost', 'induced', 'large', 'subst...
# 29   ['comprehensive', 'indicator', 'set', 'measuri...
# ..                                                 ...
# 869  ['assessment', 'chinas', 'climate', 'commitmen...
# 870  ['energy', 'access', 'transition', 'cleaner', ...
# 871  ['chinas', 'clean', 'energy', 'target', 'consi...
# 872  ['reallife', 'effectiveness', 'improved', 'sto...
# 873  ['clean', 'fuels', 'resourcepoor', 'settings',...
# 874  ['adverse', 'health', 'impacts', 'cooking', 'k...
# 875  ['indian', 'national', 'initiative', 'advanced...
# 876  ['rural', 'household', 'fuel', 'energy', 'tran...
# 877  ['outlook', 'clean', 'air', 'context', 'sustai...
# 878  ['production', 'hydrogen', 'fuel', 'renewable'...
# 879  ['much', 'alternative', 'cookstoves', 'reduce'...
# 880  ['environmental', 'health', 'china', 'progress...
# 881  ['cooking', 'season', 'risk', 'factors', 'acut...
# 882  ['effect', 'hydrogen', 'supplementation', 'eng...
# 883  ['bio', 'energy', 'production', 'using', 'carb...
# 884  ['us', 'energy', 'independence', 'assessment',...
# 885  ['modelling', 'smart', 'domestic', 'energy', '...
# 886  ['biogas', 'potential', 'renewable', 'energy',...
# 887  ['greenhouse', 'gas', 'emissions', 'reduction'...
# 888  ['green', 'renewable', 'biodiesel', 'produce',...
# 889  ['lca', 'solar', 'heating', 'cooling', 'system...
# 890  ['exergy', 'analysis', 'chemical', 'processes'...
# 891  ['green', 'revolution', 'human', 'resource', '...
# 892  ['upcoming', 'power', 'crisis', 'india', 'incr...
# 893  ['emissions', 'mitigation', 'infrastructure', ...
# 894  ['africa', 'sustainable', 'energy', 'goal', 'f...
# 895  ['scalingup', 'sustainable', 'renewable', 'ene...
# 896  ['brief', 'review', 'application', 'laser', 'b...
# 897  ['electric', 'vehicles', 'impacts', 'integrati...
# 898  ['leading', 'global', 'energy', 'environmental...
#
# [899 rows x 9 columns]

# %%
sdg_df = sdg_df.drop(['Unnamed: 0'],axis = 1)
sdg_df
# Out:
#      extracted                                 extracted_abstract  \
# 0         True  paper attempts empirically analyze compatibili...
# 1         True  aim study determine nature relationship renewa...
# 2         True  study combines panel data techniques wavelet s...
# 3         True  environmental issues dependence fossil fuel so...
# 4         True  environmental issues dependence fossil fuel so...
# 5         True  blockchain technology ushering nothing short d...
# 6         True  blockchain technology ushering nothing short d...
# 7         True  paper estimates impact renewable energy econom...
# 8         True  paper estimates impact renewable energy econom...
# 9         True  increasing concerns environmental economic imp...
# 10        True  increasing concerns environmental economic imp...
# 11        True  account continuously increasing electricity co...
# 12        True  account continuously increasing electricity co...
# 13        True  paper aims analyze interaction renewable energ...
# 14        True  paper aims analyze interaction renewable energ...
# 15        True  middle east north africa mena countries recent...
# 16        True  middle east north africa mena countries recent...
# 17        True  study investigates dynamic directional informa...
# 18        True  study investigates dynamic directional informa...
# 19        True  united nations announced new sustainable devel...
# 20        True  united nations announced new sustainable devel...
# 21       False  current study discusses linear nonlinear relat...
# 22       False  current study discusses linear nonlinear relat...
# 23        True  renewable energy sources solar panels energy s...
# 24       False  currently european union eu population live ho...
# 25        True  republic ghana aims develop utilise renewable ...
# 26       False  major challenge facing humans st century strik...
# 27        True  despite increasing cost competitiveness contin...
# 28        True  paper explains adverse effects due massive inj...
# 29        True  paper develop quantitative indicator approach ...
# ..         ...                                                ...
# 869       True  study analyzes effects impacts policies could ...
# 870      False  easy energy access trigger human social econom...
# 871      False  china proposed clean energy target together cl...
# 872       True  background billion people cook solid fuels res...
# 873       True  background access sustained adoption clean hou...
# 874       True  background kerosene recently considered relati...
# 875      False  india recently launched national biomass cooks...
# 876      False  rural household access clean affordable modern...
# 877      False  air pollution linked many united nations susta...
# 878      False  understanding scale nature hydrogens potential...
# 879      False  evidence north india despite widespread global...
# 880      False  environmental risk factors especially air wate...
# 881       True  background acute lower respiratory infections ...
# 882       True  abstractabstract vehicular pollution environme...
# 883       True  abstract worlds climate gradually altered burn...
# 884      False  two primary objectives recent energy initiativ...
# 885       True  abstractthe increasing price fossil fuels coup...
# 886      False  associated harmful environmental health social...
# 2    ['energy', 'consumption', 'gdp', 'revisited', ...
# 3    ['multiple', 'perspective', 'modeling', 'simul...
# 4    ['multiple', 'perspective', 'modeling', 'simul...
# 5    ['integrating', 'blockchain', 'technology', 'e...
# 6    ['integrating', 'blockchain', 'technology', 'e...
# 7    ['renewable', 'energy', 'consumption', 'econom...
# 8    ['renewable', 'energy', 'consumption', 'econom...
# 9    ['optimal', 'renewable', 'energy', 'supply', '...
# 10   ['optimal', 'renewable', 'energy', 'supply', '...
# 11   ['review', 'recent', 'sizing', 'methodologies'...
# 12   ['review', 'recent', 'sizing', 'methodologies'...
# 13   ['renewable', 'energy', 'consumption', 'indust...
# 14   ['renewable', 'energy', 'consumption', 'indust...
# 15   ['governance', 'renewable', 'energy', 'investm...
# 16   ['governance', 'renewable', 'energy', 'investm...
# 17   ['dynamic', 'dependence', 'fossil', 'energy', ...
# 18   ['dynamic', 'dependence', 'fossil', 'energy', ...
# 19   ['novel', 'renewable', 'energy', 'selection', ...
# 20   ['novel', 'renewable', 'energy', 'selection', ...
# 21   ['renewable', 'nonrenewable', 'categories', 'e...
# 22   ['renewable', 'nonrenewable', 'categories', 'e...
# 23   ['effect', 'increased', 'buildingintegrated', ...
# 24   ['energy', 'consumption', 'heating', 'costs', ...
# 25   ['ghana', 'achieve', 'renewable', 'energy', 't...
# 26   ['renewable', 'energy', 'consumption', 'eu', '...
# 27   ['dismantling', 'renewable', 'energy', 'polici...
# 28   ['storage', 'cost', 'induced', 'large', 'subst...
# 29   ['comprehensive', 'indicator', 'set', 'measuri...
# ..                                                 ...
# 869  ['assessment', 'chinas', 'climate', 'commitmen...
# 870  ['energy', 'access', 'transition', 'cleaner', ...
# 871  ['chinas', 'clean', 'energy', 'target', 'consi...
# 872  ['reallife', 'effectiveness', 'improved', 'sto...
# 873  ['clean', 'fuels', 'resourcepoor', 'settings',...
# 874  ['adverse', 'health', 'impacts', 'cooking', 'k...
# 875  ['indian', 'national', 'initiative', 'advanced...
# 876  ['rural', 'household', 'fuel', 'energy', 'tran...
# 877  ['outlook', 'clean', 'air', 'context', 'sustai...
# 878  ['production', 'hydrogen', 'fuel', 'renewable'...
# 879  ['much', 'alternative', 'cookstoves', 'reduce'...
# 880  ['environmental', 'health', 'china', 'progress...
# 881  ['cooking', 'season', 'risk', 'factors', 'acut...
# 882  ['effect', 'hydrogen', 'supplementation', 'eng...
# 883  ['bio', 'energy', 'production', 'using', 'carb...
# 884  ['us', 'energy', 'independence', 'assessment',...
# 885  ['modelling', 'smart', 'domestic', 'energy', '...
# 886  ['biogas', 'potential', 'renewable', 'energy',...
# 887  ['greenhouse', 'gas', 'emissions', 'reduction'...
# 888  ['green', 'renewable', 'biodiesel', 'produce',...
# 889  ['lca', 'solar', 'heating', 'cooling', 'system...
# 890    ['exergy', 'analysis', 'chemical', 'processes']
# 891  ['green', 'revolution', 'human', 'resource', '...
# 892  ['upcoming', 'power', 'crisis', 'india', 'incr...
# 893  ['emissions', 'mitigation', 'infrastructure', ...
# 894  ['africa', 'sustainable', 'energy', 'goal', 'f...
# 895  ['scalingup', 'sustainable', 'renewable', 'ene...
# 896  ['brief', 'review', 'application', 'laser', 'b...
# 897  ['electric', 'vehicles', 'impacts', 'integrati...
# 898  ['leading', 'global', 'energy', 'environmental...
#
#                           extracted_abstract_tokenized  \
# 0    ['paper', 'attempts', 'empirically', 'analyze'...
# 1    ['aim', 'study', 'determine', 'nature', 'relat...
# 2    ['study', 'combines', 'panel', 'data', 'techni...
# 3    ['environmental', 'issues', 'dependence', 'fos...
# 4    ['environmental', 'issues', 'dependence', 'fos...
# 5    ['blockchain', 'technology', 'ushering', 'noth...
# 6    ['blockchain', 'technology', 'ushering', 'noth...
# 7    ['paper', 'estimates', 'impact', 'renewable', ...
# 8    ['paper', 'estimates', 'impact', 'renewable', ...
# 9    ['increasing', 'concerns', 'environmental', 'e...
# 10   ['increasing', 'concerns', 'environmental', 'e...
# 11   ['account', 'continuously', 'increasing', 'ele...
# 12   ['account', 'continuously', 'increasing', 'ele...
# 13   ['paper', 'aims', 'analyze', 'interaction', 'r...
# 14   ['paper', 'aims', 'analyze', 'interaction', 'r...
# 15   ['middle', 'east', 'north', 'africa', 'mena', ...
# 16   ['middle', 'east', 'north', 'africa', 'mena', ...
# 17   ['study', 'investigates', 'dynamic', 'directio...
# 18   ['study', 'investigates', 'dynamic', 'directio...
# 19   ['united', 'nations', 'announced', 'new', 'sus...
# 20   ['united', 'nations', 'announced', 'new', 'sus...
# 21   ['current', 'study', 'discusses', 'linear', 'n...
# 22   ['current', 'study', 'discusses', 'linear', 'n...
# 23   ['renewable', 'energy', 'sources', 'solar', 'p...
# 24   ['currently', 'european', 'union', 'eu', 'popu...
# 25   ['republic', 'ghana', 'aims', 'develop', 'util...
# 26   ['major', 'challenge', 'facing', 'humans', 'st...
# 27   ['despite', 'increasing', 'cost', 'competitive...
# 28   ['paper', 'explains', 'adverse', 'effects', 'd...
# 29   ['paper', 'develop', 'quantitative', 'indicato...
# ..                                                 ...
# 869  ['study', 'analyzes', 'effects', 'impacts', 'p...
# 870  ['easy', 'energy', 'access', 'trigger', 'human...
# 871  ['china', 'proposed', 'clean', 'energy', 'targ...
# 872  ['background', 'billion', 'people', 'cook', 's...
# 873  ['background', 'access', 'sustained', 'adoptio...
# 874  ['background', 'kerosene', 'recently', 'consid...
# 875  ['india', 'recently', 'launched', 'national', ...
# 876  ['rural', 'household', 'access', 'clean', 'aff...
# 877  ['air', 'pollution', 'linked', 'many', 'united...
# 878  ['understanding', 'scale', 'nature', 'hydrogen...
# 879  ['evidence', 'north', 'india', 'despite', 'wid...
# 880  ['environmental', 'risk', 'factors', 'especial...
# 881  ['background', 'acute', 'lower', 'respiratory'...
# 882  ['abstractabstract', 'vehicular', 'pollution',...
# 883  ['abstract', 'worlds', 'climate', 'gradually',...
# 884  ['two', 'primary', 'objectives', 'recent', 'en...
# 885  ['abstractthe', 'increasing', 'price', 'fossil...
# 886  ['associated', 'harmful', 'environmental', 'he...
# 887  ['abstract', 'abstract', 'chinese', 'energy', ...
# 888  ['abstract', 'abstract', 'green', 'renewable',...
# 889  ['development', 'renewable', 'energy', 'techno...
# 890  ['abstract', 'exergy', 'analysis', 'exa', 'gai...
# 891  ['introductionmahatma', 'gandhi', 'said', 'nat...
# 892  ['abstract', 'world', 'modernization', 'every'...
# 893  ['abstract', 'order', 'foster', 'development',...
# 894  ['sustainable', 'development', 'goal', 'sdg', ...
# 895  ['three', 'processes', 'urbanization', 'indust...
# 896  ['abstract', 'bioenergy', 'production', 'bioma...
# 897  ['exponential', 'rise', 'electricity', 'demand...
# 898  ['recent', 'years', 'ten', 'member', 'countrie...
#
#                                 initial_text_tokenized
# 0    ['trade', 'liberalization', 'policies', 'align...
# 1    ['oil', 'prices', 'macroeconomic', 'factors', ...
# 2    ['energy', 'consumption', 'gdp', 'revisited', ...
# 3    ['multiple', 'perspective', 'modeling', 'simul...
# 4    ['multiple', 'perspective', 'modeling', 'simul...
# 5    ['integrating', 'blockchain', 'technology', 'e...
# 6    ['integrating', 'blockchain', 'technology', 'e...
# 7    ['renewable', 'energy', 'consumption', 'econom...
# 8    ['renewable', 'energy', 'consumption', 'econom...
# 9    ['optimal', 'renewable', 'energy', 'supply', '...
# 10   ['optimal', 'renewable', 'energy', 'supply', '...
# 11   ['review', 'recent', 'sizing', 'methodologies'...
# 12   ['review', 'recent', 'sizing', 'methodologies'...
# 13   ['renewable', 'energy', 'consumption', 'indust...
# 14   ['renewable', 'energy', 'consumption', 'indust...
# 15   ['governance', 'renewable', 'energy', 'investm...
# 16   ['governance', 'renewable', 'energy', 'investm...
# 17   ['dynamic', 'dependence', 'fossil', 'energy', ...
# 18   ['dynamic', 'dependence', 'fossil', 'energy', ...
# 19   ['novel', 'renewable', 'energy', 'selection', ...
# 20   ['novel', 'renewable', 'energy', 'selection', ...
# 21   ['renewable', 'nonrenewable', 'categories', 'e...
# 22   ['renewable', 'nonrenewable', 'categories', 'e...
# 23   ['effect', 'increased', 'buildingintegrated', ...
# 24   ['energy', 'consumption', 'heating', 'costs', ...
# 25   ['ghana', 'achieve', 'renewable', 'energy', 't...
# 26   ['renewable', 'energy', 'consumption', 'eu', '...
# 27   ['dismantling', 'renewable', 'energy', 'polici...
# 28   ['storage', 'cost', 'induced', 'large', 'subst...
# 29   ['comprehensive', 'indicator', 'set', 'measuri...
# ..                                                 ...
# 869  ['assessment', 'chinas', 'climate', 'commitmen...
# 870  ['energy', 'access', 'transition', 'cleaner', ...
# 871  ['chinas', 'clean', 'energy', 'target', 'consi...
# 872  ['reallife', 'effectiveness', 'improved', 'sto...
# 873  ['clean', 'fuels', 'resourcepoor', 'settings',...
# 874  ['adverse', 'health', 'impacts', 'cooking', 'k...
# 875  ['indian', 'national', 'initiative', 'advanced...
# 876  ['rural', 'household', 'fuel', 'energy', 'tran...
# 877  ['outlook', 'clean', 'air', 'context', 'sustai...
# 878  ['production', 'hydrogen', 'fuel', 'renewable'...
# 879  ['much', 'alternative', 'cookstoves', 'reduce'...
# 880  ['environmental', 'health', 'china', 'progress...
# 881  ['cooking', 'season', 'risk', 'factors', 'acut...
# 882  ['effect', 'hydrogen', 'supplementation', 'eng...
# 883  ['bio', 'energy', 'production', 'using', 'carb...
# 884  ['us', 'energy', 'independence', 'assessment',...
# 885  ['modelling', 'smart', 'domestic', 'energy', '...
# 886  ['biogas', 'potential', 'renewable', 'energy',...
# 887  ['greenhouse', 'gas', 'emissions', 'reduction'...
# 888  ['green', 'renewable', 'biodiesel', 'produce',...
# 889  ['lca', 'solar', 'heating', 'cooling', 'system...
# 890  ['exergy', 'analysis', 'chemical', 'processes'...
# 891  ['green', 'revolution', 'human', 'resource', '...
# 892  ['upcoming', 'power', 'crisis', 'india', 'incr...
# 893  ['emissions', 'mitigation', 'infrastructure', ...
# 894  ['africa', 'sustainable', 'energy', 'goal', 'f...
# 895  ['scalingup', 'sustainable', 'renewable', 'ene...
# 896  ['brief', 'review', 'application', 'laser', 'b...
# 897  ['electric', 'vehicles', 'impacts', 'integrati...
# 898  ['leading', 'global', 'energy', 'environmental...
#
# [899 rows x 8 columns]

# %%
X = sdg_df.drop(['sdg','initial_text','extracted', 'extracted_title_tokenized', 'extracted_abstract_tokenized','initial_text_tokenized'], axis=1)
y = sdg_df['sdg']
X
# Out:
#                                     extracted_abstract  \
# 0    paper attempts empirically analyze compatibili...
# 1    aim study determine nature relationship renewa...
# 2    study combines panel data techniques wavelet s...
# 3    environmental issues dependence fossil fuel so...
# 4    environmental issues dependence fossil fuel so...
# 5    blockchain technology ushering nothing short d...
# 6    blockchain technology ushering nothing short d...
# 7    paper estimates impact renewable energy econom...
# 8    paper estimates impact renewable energy econom...
# 9    increasing concerns environmental economic imp...
# 10   increasing concerns environmental economic imp...
# 11   account continuously increasing electricity co...
# 12   account continuously increasing electricity co...
# 13   paper aims analyze interaction renewable energ...
# 14   paper aims analyze interaction renewable energ...
# 15   middle east north africa mena countries recent...
# 16   middle east north africa mena countries recent...
# 17   study investigates dynamic directional informa...
# 18   study investigates dynamic directional informa...
# 19   united nations announced new sustainable devel...
# 20   united nations announced new sustainable devel...
# 21   current study discusses linear nonlinear relat...
# 22   current study discusses linear nonlinear relat...
# 23   renewable energy sources solar panels energy s...
# 24   currently european union eu population live ho...
# 25   republic ghana aims develop utilise renewable ...
# 26   major challenge facing humans st century strik...
# 27   despite increasing cost competitiveness contin...
# 28   paper explains adverse effects due massive inj...
# 29   paper develop quantitative indicator approach ...
# ..                                                 ...
# 869  study analyzes effects impacts policies could ...
# 870  easy energy access trigger human social econom...
# 871  china proposed clean energy target together cl...
# 872  background billion people cook solid fuels res...
# 873  background access sustained adoption clean hou...
# 874  background kerosene recently considered relati...
# 875  india recently launched national biomass cooks...
# 876  rural household access clean affordable modern...
# 877  air pollution linked many united nations susta...
# 878  understanding scale nature hydrogens potential...
# 879  evidence north india despite widespread global...
# 880  environmental risk factors especially air wate...
# 881  background acute lower respiratory infections ...
# 882  abstractabstract vehicular pollution environme...
# 883  abstract worlds climate gradually altered burn...
# 884  two primary objectives recent energy initiativ...
# 885  abstractthe increasing price fossil fuels coup...
# 886  associated harmful environmental health social...
# 887  abstract abstract chinese energy system major ...
# 888  abstract abstract green renewable biodiesel pr...
# 889  development renewable energy technologies crit...
# 890  abstract exergy analysis exa gaining relevance...
# 891  introductionmahatma gandhi said nature enough ...
# 892  abstract world modernization every country tri...
# 893  abstract order foster development nations high...
# 894  sustainable development goal sdg focuses ensur...
# 895  three processes urbanization industrialization...
# 896  abstract bioenergy production biomass sources ...
# 897  exponential rise electricity demand become pri...
# 898  recent years ten member countries association ...
#
#                                        extracted_title
# 0    trade liberalization policies aligned renewabl...
# 1    oil prices macroeconomic factors policies affe...
# 2    energy consumption gdp revisited new panel dat...
# 3    multiple perspective modeling simulation appro...
# 4    multiple perspective modeling simulation appro...
# 5    integrating blockchain technology energy secto...
# 6    integrating blockchain technology energy secto...
# 7    renewable energy consumption economic growth n...
# 8    renewable energy consumption economic growth n...
# 9    optimal renewable energy supply choices netzer...
# 10   optimal renewable energy supply choices netzer...
# 11   review recent sizing methodologies hybrid rene...
# 12   review recent sizing methodologies hybrid rene...
# 13   renewable energy consumption industrial produc...
# 14   renewable energy consumption industrial produc...
# 15   governance renewable energy investment mena co...
# 16   governance renewable energy investment mena co...
# 17   dynamic dependence fossil energy investor sent...
# 18   dynamic dependence fossil energy investor sent...
# 19   novel renewable energy selection model united ...
# 20   novel renewable energy selection model united ...
# 21   renewable nonrenewable categories energy consu...
# 22   renewable nonrenewable categories energy consu...
# 23   effect increased buildingintegrated renewable ...
# 24   energy consumption heating costs detached hous...
# 25   ghana achieve renewable energy target electric...
# 26   renewable energy consumption eu countries poli...
# 27   dismantling renewable energy policies cases sp...
# 28   storage cost induced large substitution nuclea...
# 29   comprehensive indicator set measuring multiple...
# ..                                                 ...
# 869  assessment chinas climate commitment nonfossil...
# 870  energy access transition cleaner cooking fuels...
# 871  chinas clean energy target consistency pathway...
# 872  reallife effectiveness improved stoves clean f...
# 873  clean fuels resourcepoor settings systematic r...
# 874  adverse health impacts cooking kerosene multic...
# 875  indian national initiative advanced biomass co...
# 876  rural household fuel energy transition evidenc...
# 877  outlook clean air context sustainable developm...
# 878  production hydrogen fuel renewable sources rol...
# 879  much alternative cookstoves reduce biomass fue...
# 880  environmental health china progress towards cl...
# 881  cooking season risk factors acute lower respir...
# 882  effect hydrogen supplementation engine perform...
# 883  bio energy production using carbon based elect...
# 884  us energy independence assessment mechanisms h...
# 885            modelling smart domestic energy systems
# 886  biogas potential renewable energy source ghana...
# 887  greenhouse gas emissions reduction china clean...
# 888  green renewable biodiesel produce oil hydrodeo...
# 889  lca solar heating cooling system equipped smal...
# 890                 exergy analysis chemical processes
# 891         green revolution human resource management
# 892  upcoming power crisis india increasing electri...
# 893  emissions mitigation infrastructure improvemen...
# 894  africa sustainable energy goal focus access re...
# 895  scalingup sustainable renewable energy generat...
# 896  brief review application laser biotechnology e...
# 897  electric vehicles impacts integration power gr...
# 898  leading global energy environmental transforma...
#
# [899 rows x 2 columns]

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
y = label_encoder.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
X_title_train = X_train['extracted_title']
X_abstract_train = X_train['extracted_abstract']
X_title_test = X_test['extracted_title']
X_abstract_test = X_test['extracted_abstract']

maxlen = 300
tokenizer = Tokenizer(num_words=50000)
word_index = tokenizer.word_index

tokenizer.fit_on_texts(X_title_train.astype(str))
X_title_train = tokenizer.texts_to_sequences(X_title_train.astype(str))
X_title_train = pad_sequences(X_title_train, padding='post', maxlen=maxlen)

tokenizer.fit_on_texts(X_abstract_train.astype(str))
X_abstract_train = tokenizer.texts_to_sequences(X_abstract_train.astype(str))
X_abstract_train = pad_sequences(X_abstract_train, padding='post', maxlen=maxlen)

tokenizer.fit_on_texts(X_title_test.astype(str))
X_title_test = tokenizer.texts_to_sequences(X_title_test.astype(str))
X_title_test = pad_sequences(X_title_test, padding='post', maxlen=maxlen)

tokenizer.fit_on_texts(X_abstract_test.astype(str))
X_abstract_test = tokenizer.texts_to_sequences(X_abstract_test.astype(str))
X_abstract_test = pad_sequences(X_abstract_test, padding='post', maxlen=maxlen)

word_index = tokenizer.word_index
vocab_size = len(tokenizer.word_index) + 1
maxlen = 300
#X_title_train = tokenizer.texts_to_sequences(X1_train)
#X1_test = tokenizer.texts_to_sequences(X1_test)

#X1_train = pad_sequences(X1_train, padding='post', maxlen=maxlen)
#X1_test = pad_sequences(X1_test, padding='post', maxlen=maxlen)
X_title_test
# Out:
# array([[1215, 1547, 1760, ...,    0,    0,    0],
#        [1735,  690,   18, ...,    0,    0,    0],
#        [ 130,  389,   18, ...,    0,    0,    0],
#        ...,
#        [  21,  118,  770, ...,    0,    0,    0],
#        [ 949,   22,    5, ...,    0,    0,    0],
#        [1206,  466,  122, ...,    0,    0,    0]])

# %%
vocab_size
# Out:
# 13201

# %%
input_1 = Input(shape=(maxlen,))
input_2 = Input(shape=(maxlen,))

# %%
embedding1 = Embedding(vocab_size, 300)(input_1)
conv1 = Conv1D(filters=128, kernel_size=4, activation='relu')(embedding1)
drop1 = Dropout(0.5)(conv1)
pool1 = MaxPooling1D(pool_size=2)(drop1)
flat1 = Flatten()(pool1)


embedding2 = Embedding(vocab_size, 300)(input_2)
conv2 = Conv1D(filters=128, kernel_size=4, activation='relu')(embedding2)
drop2 = Dropout(0.5)(conv2)
pool2 = MaxPooling1D(pool_size=2)(drop2)
flat2 = Flatten()(pool2)

merged = concatenate([flat1, flat2])
dense1 = Dense(10, activation='relu')(merged)
outputs = Dense(6, activation='softmax')(dense1)
model = Model(inputs=[input_1, input_2], outputs=outputs)
# compile
model.compile(loss='binary_crossentropy',
              optimizer='adam', 
              metrics=['accuracy'])
# summarize
print(model.summary())
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 300)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 300, 300)     3960300     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 300, 300)     3960300     input_2[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 297, 128)     153728      embedding[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 297, 128)     153728      embedding_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 297, 128)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 297, 128)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 148, 128)     0           dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 148, 128)     0           dropout_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 18944)        0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 18944)        0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 37888)        0           flatten[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           378890      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 6)            66          dense[0][0]
# ==================================================================================================
# Total params: 8,607,012
# Trainable params: 8,607,012
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model

plot_model(model,
           to_file='model_plot_cnn.png',
           show_shapes=True,
           show_layer_names=True)

# %%
from tensorflow.python.keras.callbacks import EarlyStopping

# setting the early stoping callback
es = EarlyStopping(monitor='val_loss',
                   patience=4,
                   verbose=2,
                   restore_best_weights=True)

# %%
model.fit(x=[X_title_train, X_abstract_train], 
          y = y_train,                
          batch_size=64, 
          epochs=30,
          verbose=1,
          validation_split=0.15, 
          callbacks=[es])
# Out:
# Epoch 1/30
# 10/10 [==============================] - 5s 467ms/step - loss: 0.4270 - accuracy: 0.3079 - val_loss: 0.4093 - val_accuracy: 0.2897
# Epoch 2/30
# 10/10 [==============================] - 5s 467ms/step - loss: 0.3701 - accuracy: 0.4205 - val_loss: 0.3741 - val_accuracy: 0.3925
# Epoch 3/30
# 10/10 [==============================] - 5s 451ms/step - loss: 0.3115 - accuracy: 0.5066 - val_loss: 0.3218 - val_accuracy: 0.5421
# Epoch 4/30
# 10/10 [==============================] - 5s 475ms/step - loss: 0.2126 - accuracy: 0.6871 - val_loss: 0.2133 - val_accuracy: 0.8131
# Epoch 5/30
# 10/10 [==============================] - 5s 462ms/step - loss: 0.1310 - accuracy: 0.8493 - val_loss: 0.1690 - val_accuracy: 0.8318
# Epoch 6/30
# 10/10 [==============================] - 5s 454ms/step - loss: 0.1060 - accuracy: 0.8493 - val_loss: 0.1504 - val_accuracy: 0.8411
# Epoch 7/30
# 10/10 [==============================] - 5s 452ms/step - loss: 0.0808 - accuracy: 0.8526 - val_loss: 0.1253 - val_accuracy: 0.8505
# Epoch 8/30
# 10/10 [==============================] - 5s 460ms/step - loss: 0.0649 - accuracy: 0.8526 - val_loss: 0.1200 - val_accuracy: 0.8505
# Epoch 9/30
# 10/10 [==============================] - 5s 452ms/step - loss: 0.0581 - accuracy: 0.8642 - val_loss: 0.1229 - val_accuracy: 0.8411
# Epoch 10/30
# 10/10 [==============================] - 5s 457ms/step - loss: 0.0542 - accuracy: 0.8891 - val_loss: 0.1112 - val_accuracy: 0.8505
# Epoch 11/30
# 10/10 [==============================] - 5s 457ms/step - loss: 0.0504 - accuracy: 0.8990 - val_loss: 0.1156 - val_accuracy: 0.8411
# Epoch 12/30
# 10/10 [==============================] - 5s 454ms/step - loss: 0.0448 - accuracy: 0.9288 - val_loss: 0.1154 - val_accuracy: 0.8411
# Epoch 13/30
# 10/10 [==============================] - 5s 468ms/step - loss: 0.0387 - accuracy: 0.9305 - val_loss: 0.1185 - val_accuracy: 0.8224
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9404Restoring model weights from the end of the best epoch.
# 10/10 [==============================] - 5s 470ms/step - loss: 0.0310 - accuracy: 0.9404 - val_loss: 0.1125 - val_accuracy: 0.8692
# Epoch 00014: early stopping

# %%
model.evaluate([X_title_test, X_abstract_test], y_test, verbose=2)
# Out:
# 6/6 - 0s - loss: 0.4120 - accuracy: 0.5449
# [0.4120340645313263, 0.5449438095092773]
